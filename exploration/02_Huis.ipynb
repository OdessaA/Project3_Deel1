# %% [markdown]
# # Notebook 02: Huis Data Exploratie

# %%
import pandas as pd
from pathlib import Path

DATA_DIR = Path.cwd().parent / "locatie_data"

# %%
df_huis = pd.read_parquet(
    DATA_DIR / "huis788.parquet"
)

# %%
df_huis.head()
# Out:
#                   timestamp       CO2        CTYPE                ENAME  \
# 0 2024-03-08 01:00:00+01:00       NaN  electricity  boiler-16eda211b788
# 1 2024-03-08 01:05:00+01:00  0.099741  electricity  boiler-16eda211b788
# 2 2024-03-08 01:10:00+01:00  0.099513  electricity  boiler-16eda211b788
# 3 2024-03-08 01:15:00+01:00  0.099084  electricity  boiler-16eda211b788
# 4 2024-03-08 01:20:00+01:00  0.099326  electricity  boiler-16eda211b788
#
#         ENE            EONNAME   ETYPE   GNAME       POW  CO2_IMP  ...  \
# 0       NaN  eiot-16eda211b788  boiler  SERENE  6.504839      NaN  ...
# 1  0.542070  eiot-16eda211b788  boiler  SERENE  6.490000      NaN  ...
# 2  0.540833  eiot-16eda211b788  boiler  SERENE  6.461972      NaN  ...
# 3  0.538498  eiot-16eda211b788  boiler  SERENE  6.477778      NaN  ...
# 4  0.539815  eiot-16eda211b788  boiler  SERENE  6.461039      NaN  ...
#
#    CO2_EXP COST  COST_EXP  ENE_CNT_EXP  ENE_EXP  CO2EQ  ESTYPE  forecast.ENE  \
# ...

# %%
df_huis.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 3057890 entries, 0 to 3057889
# Data columns (total 24 columns):
#  #   Column        Dtype
# ---  ------        -----
#  0   timestamp     datetime64[us, Europe/Amsterdam]
#  1   CO2           float64
#  2   CTYPE         str
#  3   ENAME         str
#  4   ENE           float64
#  5   EONNAME       str
#  6   ETYPE         str
#  7   GNAME         str
#  8   POW           float64
#  9   CO2_IMP       float64
#  10  COST_IMP      float64
#  11  CTYPEC        str
#  12  ENE_CNT_IMP   float64
#  13  ENE_IMP       float64
#  14  CO2_EXP       float64
#  15  COST          float64
#  16  COST_EXP      float64
#  17  ENE_CNT_EXP   float64
#  18  ENE_EXP       float64
#  19  CO2EQ         float64
#  20  ESTYPE        str
#  21  forecast.ENE  float64
#  22  forecast.POW  float64
#  23  PRICE         float64
# dtypes: datetime64[us, Europe/Amsterdam](1), float64(16), str(7)
# memory usage: 716.3 MB

# %%
df_huis.describe().T
# Out:
#                   count          mean           std           min  \
# CO2            940640.0  4.753729e+00  9.093405e+02 -5.180328e+03
# ENE           1422314.0  6.184638e+05  7.607598e+07 -6.432414e+06
# POW           1121431.0  2.119905e+02  7.537093e+02 -3.456934e+03
# CO2_IMP        707954.0  6.631111e+00  1.048100e+03  0.000000e+00
# COST_IMP      1122989.0  2.004792e+02  2.182276e+04  0.000000e+00
# ENE_CNT_IMP   1123353.0  1.385691e+09  3.324023e+09 -1.393403e+06
# ENE_IMP       1141386.0  7.763103e+05  8.519306e+07  0.000000e+00
# CO2_EXP        691716.0  1.954165e+00  1.012028e+01 -4.480111e+01
# COST          1133980.0  1.970967e+02  2.164793e+04 -1.634373e+03
# COST_EXP      1124254.0  1.451793e+00  1.026791e+02  0.000000e+00
# ENE_CNT_EXP   1124617.0  8.836919e+06  1.299611e+07  0.000000e+00
# ENE_EXP       1126580.0  5.701995e+03  4.036976e+05 -1.163333e+02
# CO2EQ          168068.0  2.737777e+02  1.374936e+02  2.300000e+01
# ...
