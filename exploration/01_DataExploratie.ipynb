# %% [markdown]
# # Notebook 01: Data Exploratie

# %%
from pathlib import Path
from zipfile import ZipFile
import pandas as pd

BASE_DIR = Path.cwd().parent / "datasets iecon" / "datasets iecon" # Pad naar de datasets map

# %% [markdown]
# ### 1. Data inladen en drie DataFrames maken (huis, middenhuis, carport)

# %%
def read_location(location_path):
    dfs = [] # Lege lijst waar de losse dfs in komen

    zip_files = list(location_path.rglob("*.zip")) # Zoekt in de datasets map en alle submappen naar alle bestanden die eindigen op .zip. rglob zorgt ervoor dat er ook in de submappen gezocht wordt. 

    print(f"{location_path.name}: {len(zip_files)} ZIP-bestanden gevonden") # Print hoeveel zip bestanden er gevonden zijn

    for i, zip_path in enumerate(zip_files, 1): # Loop door alle zip bestanden. enumerate(..,1) geeft elk bestand een teller mee die begint bij 1 (dit is voor de voortgang print per 500 bestanden hieronder.)
        with ZipFile(zip_path) as z: # opent 1 zip bestand tegelijk

            # vraagt alle bestandnamen op en houdt bestanden die eindigen op .csv 
            csv_files = [file for file in z.namelist()
                if file.endswith(".csv")]

            # loop door de csv bestanden binnen deze zip
            for csv_file in csv_files:

                # opent de csv direct zonder de zip eerst uit te pakken
                with z.open(csv_file) as f: 
                    
                    #lees de csv in al pandas dataframe en voegt het toe aan de dfs lijst 
                    dfs.append(pd.read_csv(f))

        # Elke 500 zip bestanden laat de code zien hoever hij is
        if i % 500 == 0:
            print(f"{i}/{len(zip_files)} verwerkt")

    # voegt alle losse dataframes uit dfs onder elkaar samen 
    return pd.concat(dfs, ignore_index=True)

# %%
df_huis_788 = read_location(BASE_DIR / "eiot-16eda211b788")
df_middenhuis_479 = read_location(BASE_DIR / "eiot-5335bae8d497")
df_carport = read_location(BASE_DIR / "eiot-e4393cd3dfdb")
# Out:
# eiot-16eda211b788: 7294 ZIP-bestanden gevonden
# 500/7294 verwerkt
# 1000/7294 verwerkt
# 1500/7294 verwerkt
# 2000/7294 verwerkt
# 2500/7294 verwerkt
# 3000/7294 verwerkt
# 3500/7294 verwerkt
# 4000/7294 verwerkt
# 4500/7294 verwerkt
# 5000/7294 verwerkt
# 5500/7294 verwerkt
# 6000/7294 verwerkt
# 6500/7294 verwerkt
# 7000/7294 verwerkt
# eiot-5335bae8d497: 8556 ZIP-bestanden gevonden
# 500/8556 verwerkt
# 1000/8556 verwerkt
# 1500/8556 verwerkt
# 2000/8556 verwerkt
# 2500/8556 verwerkt
# 3000/8556 verwerkt
# 3500/8556 verwerkt
# 4000/8556 verwerkt
# 4500/8556 verwerkt
# 5000/8556 verwerkt
# 5500/8556 verwerkt
# 6000/8556 verwerkt
# 6500/8556 verwerkt
# 7000/8556 verwerkt
# 7500/8556 verwerkt
# 8000/8556 verwerkt
# 8500/8556 verwerkt
# eiot-e4393cd3dfdb: 11447 ZIP-bestanden gevonden
# 500/11447 verwerkt
# 1000/11447 verwerkt
# 1500/11447 verwerkt
# 2000/11447 verwerkt
# 2500/11447 verwerkt
# 3000/11447 verwerkt
# 3500/11447 verwerkt
# 4000/11447 verwerkt
# 4500/11447 verwerkt
# 5000/11447 verwerkt
# 5500/11447 verwerkt
# 6000/11447 verwerkt
# 6500/11447 verwerkt
# 7000/11447 verwerkt
# 7500/11447 verwerkt
# 8000/11447 verwerkt
# 8500/11447 verwerkt
# 9000/11447 verwerkt
# 9500/11447 verwerkt
# 10000/11447 verwerkt
# 10500/11447 verwerkt
# 11000/11447 verwerkt

# %%
print(df_huis_788.shape)
print(df_middenhuis_479.shape)
print(df_carport.shape)
# Out:
# (3057890, 24)
# (3493093, 24)
# (4888431, 24)

# %% [markdown]
# ### 2. Huis Data Exploratie

# %%
df_huis_788.head()
# Out:
#                   Unnamed: 0       CO2        CTYPE                ENAME  \
# 0  2024-03-08 00:00:00+00:00       NaN  electricity  boiler-16eda211b788
# 1  2024-03-08 00:05:00+00:00  0.099741  electricity  boiler-16eda211b788
# 2  2024-03-08 00:10:00+00:00  0.099513  electricity  boiler-16eda211b788
# 3  2024-03-08 00:15:00+00:00  0.099084  electricity  boiler-16eda211b788
# 4  2024-03-08 00:20:00+00:00  0.099326  electricity  boiler-16eda211b788
#
#         ENE            EONNAME   ETYPE   GNAME       POW  CO2_IMP  ...  \
# 0       NaN  eiot-16eda211b788  boiler  SERENE  6.504839      NaN  ...
# 1  0.542070  eiot-16eda211b788  boiler  SERENE  6.490000      NaN  ...
# 2  0.540833  eiot-16eda211b788  boiler  SERENE  6.461972      NaN  ...
# 3  0.538498  eiot-16eda211b788  boiler  SERENE  6.477778      NaN  ...
# 4  0.539815  eiot-16eda211b788  boiler  SERENE  6.461039      NaN  ...
#
#    CO2_EXP COST  COST_EXP  ENE_CNT_EXP  ENE_EXP  CO2EQ  ESTYPE  forecast.ENE  \
# 0      NaN  NaN       NaN          NaN      NaN    NaN     NaN           NaN
# 1      NaN  NaN       NaN          NaN      NaN    NaN     NaN           NaN
# 2      NaN  NaN       NaN          NaN      NaN    NaN     NaN           NaN
# 3      NaN  NaN       NaN          NaN      NaN    NaN     NaN           NaN
# 4      NaN  NaN       NaN          NaN      NaN    NaN     NaN           NaN
#
#    forecast.POW  PRICE
# 0           NaN    NaN
# 1           NaN    NaN
# 2           NaN    NaN
# 3           NaN    NaN
# 4           NaN    NaN
#
# [5 rows x 24 columns]

# %%
df_huis_788.columns
# Out:
# Index(['Unnamed: 0', 'CO2', 'CTYPE', 'ENAME', 'ENE', 'EONNAME', 'ETYPE',
#        'GNAME', 'POW', 'CO2_IMP', 'COST_IMP', 'CTYPEC', 'ENE_CNT_IMP',
#        'ENE_IMP', 'CO2_EXP', 'COST', 'COST_EXP', 'ENE_CNT_EXP', 'ENE_EXP',
#        'CO2EQ', 'ESTYPE', 'forecast.ENE', 'forecast.POW', 'PRICE'],
#       dtype='str')

# %%
df_huis_788.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 3057890 entries, 0 to 3057889
# Data columns (total 24 columns):
#  #   Column        Dtype
# ---  ------        -----
#  0   Unnamed: 0    str
#  1   CO2           float64
#  2   CTYPE         str
#  3   ENAME         str
#  4   ENE           float64
#  5   EONNAME       str
#  6   ETYPE         str
#  7   GNAME         str
#  8   POW           float64
#  9   CO2_IMP       float64
#  10  COST_IMP      float64
#  11  CTYPEC        str
#  12  ENE_CNT_IMP   float64
#  13  ENE_IMP       float64
#  14  CO2_EXP       float64
#  15  COST          float64
#  16  COST_EXP      float64
#  17  ENE_CNT_EXP   float64
#  18  ENE_EXP       float64
#  19  CO2EQ         float64
#  20  ESTYPE        str
#  21  forecast.ENE  float64
#  22  forecast.POW  float64
#  23  PRICE         float64
# dtypes: float64(16), str(8)
# memory usage: 559.9 MB

# %%
df_huis_788["ENAME"].value_counts()
# Out:
# ENAME
# overig-16eda211b788                          398790
# totaalverbruik-16eda211b788                  397154
# wasmachine-16eda211b788                      381248
# omvormer-16eda211b788                        368720
# boiler-16eda211b788                          362465
# wcdskeukeneilandenvaatwasser-16eda211b788    361006
# hoofdmeter-16eda211b788                      318076
# priceele_c911efafaa                          171217
# co2ele_c911efafaa                            167079
# odectprice_c911efafaa                         95109
# forec-omvormer-16eda211b788                   17300
# forec-totaalverbruik-16eda211b788             17300
# priceele_123456                                1437
# co2ele_92be2eca45                               989
# Name: count, dtype: int64

# %%
df_huis_788.isna().sum()
# Out:
# Unnamed: 0            0
# CO2             2117250
# CTYPE                 0
# ENAME                 0
# ENE             1635576
# EONNAME         2833354
# ETYPE                 0
# GNAME           2833354
# POW             1936459
# CO2_IMP         2349936
# COST_IMP        1934901
# CTYPEC          1468956
# ENE_CNT_IMP     1934537
# ENE_IMP         1916504
# CO2_EXP         2366174
# COST            1923910
# COST_EXP        1933636
# ENE_CNT_EXP     1933273
# ENE_EXP         1931310
# CO2EQ           2889822
# ESTYPE          3023290
# forecast.ENE    3040590
# forecast.POW    3040590
# PRICE           2790127
# dtype: int64
